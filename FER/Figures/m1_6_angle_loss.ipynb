# %%
import os
os.chdir("C:\\Users\\Zber\\Documents\\Dev_program\\OpenRadar")

import matplotlib._color_data as mcd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.ticker as ticker

# %%
res = [0.365368563886286, 0.3669239661943658, 0.36926132171754344, 0.36965137125218633, 0.3708223511904232, 0.3739509789648887, 0.3774809006629614, 0.3798400234741088, 0.3806274137765476, 0.3806274137765476, 0.37944651757350467, 0.37826676291049915, 0.37826676291049915, 0.37551851691947885, 0.37121295340780786, 0.3684816410697339, 0.3684816410697339, 0.36926132171754344, 0.37199456840935646, 0.38106807383925334, 0.3929987828614447, 0.40825198831389886, 0.42324302605537995, 0.44078062730345036, 0.4551347507873052, 0.4678812812351192, 0.478995276769814, 0.4875423755329495, 0.4960610318221184, 0.5065553018301435, 0.5197656107821497, 0.530459769872612, 0.5375213396501375, 0.5389280655608615, 0.5360444403505584, 0.5245028068162804, 0.5064496223633339, 0.4845534609084506, 0.46373252897629264, 0.43518482110345247, 0.40686681768085886, 0.37826676291049915, 0.349945574463947, 0.3246965120405601, 0.30169568008790315, 0.2794723154517112, 0.2567336441978597, 0.24458191652792574, 0.24070333427269652, 0.24588159214020996, 0.2544123904262106, 0.26578395420385414, 0.27739789419253275, 0.2853900052595233, 0.2888985442363007, 0.28714173665303916, 0.28399228663293635, 0.2787800169242157, 0.2756748893842697, 0.27498713648560125, 0.2756748893842697, 0.283294652431381, 0.29597616631599366, 0.31218980304050425, 0.32804270547858333, 0.3423285549945697, 0.3564705022675794, 0.3684816410697339, 0.3790531385118442, 0.38496691106586556, 0.3893208816183679, 0.39209879997851727, 0.3936886109455185, 0.3936886109455185, 0.39209879997851727, 0.3893208816183679, 0.38575748614330885, 0.38259807375791566, 0.3798400234741088, 0.37551851691947885, 0.3708223511904232, 0.3684816410697339, 0.36575719984800514, 0.36420352064577316]

# %%
colors = ['#53a8fb', '#a97ddd', '#64c44b', '#68dcf2', "#F4820B", "#FF545A", "#C775FF"]

fig2, ax2 = plt.subplots(1, 1, figsize=(8, 6))
lw = 4
offset = np.random.normal(0,0.001,19) + res[0]

rr = np.concatenate([offset, res], axis=0)

x = np.linspace(-60,60,len(rr))


txt = np.arange(-60, 61, step=20)
pos = np.linspace(-60,60,7)
ax2.set_xticks(pos)
ax2.set_xticklabels(txt,fontsize=25)

ax2.plot(x, rr, c=colors[0], linewidth=lw)


# ours = 62

# -6, +9
ax2.axvline(54-60, c=colors[2], label='Face-match', lw=3, zorder=5)
ax2.axvline(69-60, c=colors[2], lw=3, zorder=5)


# -5, +8
ax2.axvline(55-60, c=colors[5], lw=3,label='Ground Truth', linestyle='dashed')
ax2.axvline(68-60, c=colors[5], lw=3, linestyle='dashed')



ax2.set_xlabel("Angle (degree)",fontsize=35)
ax2.set_ylabel("Similarity",fontsize=35)

# ax2.axvline(1.3, linewidth = 4)

ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.yaxis.set_tick_params(labelsize=30, length=4, direction='in', width=1)
ax2.xaxis.set_tick_params(labelsize=30, length=4, direction='in', width=1)
ax2.legend(loc="upper left", prop={'size': 20, }, ncol=1, bbox_to_anchor=(0.555, 1.02), fancybox=True,
               framealpha=0.0, labelspacing=0.05, handletextpad=0.2, columnspacing=0.5, handlelength=1.5)
               
fig2.savefig('C:/Users/Zber/Desktop/mmEmo_Exp/0.Method/m1_6_angle_loss.svg', format='svg', bbox_inches="tight")
