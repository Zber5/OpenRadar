# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.ticker as ticker
from matplotlib.lines import Line2D

# %%
colors = ['#53a8fb', '#a97ddd', '#64c44b', '#68dcf2']
colors = ['#53a8fb', '#a97ddd', '#53a8fb', '#64c44b', '#68dcf2', '#FF545A']
emotion_list = ['Neutral', 'Happiness', 'Surprise','Anger', 'Sadness', 'Fear', 'Disgust']

# %%
kd = np.asarray([0.67543936, 0.3429233, -0.048263058, -0.057558905, 0.076596685, -0.023477986, -0.12846045])+1
ours = np.asarray([0.8297626, 0.67001975, 0.6317048, 0.31210327, 0.37531605, 0.22298682, 0.5658224])+1
imag = np.asarray([0.9002371, 0.75488144, 0.7042448, 0.5286966, 0.69267374, 0.7186437, 0.7337955])+1
unsup = np.asarray([0.6985147, 0.38075477, 0.2572334, -0.06282681, 0.034902457, -0.22179835, 0.37535214])+1

# %%
import matplotlib.ticker as ticker
fig, ax = plt.subplots(1, 1, figsize=(8, 5.5))
colors =['#53a8fb', '#a97ddd', '#64c44b','#68dcf2', '#FF545A', '#FFBE54']
# colors1 = ['#c2342c',#ef8636]
emotion_list = ['Neutral', 'Happiness', 'Surprise','Anger', 'Sadness', 'Fear', 'Disgust']

ind = np.arange(1, len(kd)+1)
# np.arange(1,len(sit+1))*0.9  # the x locations for the groups
width = 0.2  # the width of the bars

rects0 = ax.bar(ind - width, kd, width, edgecolor = 'black',color=colors[-1],
                label='KD',linewidth=1, bottom=-1)
rects1 = ax.bar(ind , ours, width, edgecolor='black', color=colors[-2],
                label='Our', bottom=-1)
rects3 = ax.bar(ind + width, imag, width, edgecolor='black', label='Image', color=colors[2], bottom=-1)


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel("Silhouette Score", fontsize=30)
# ax.set_xlabel("# Devices",fontsize=30)
# ax.set_title('battery variance',fontsize=18,fontweight="bold")
# ax.set_ylim(-1, 1)
ax.yaxis.set_tick_params(labelsize=25, length=5)
ax.set_xticks(ind)
ax.set_xticklabels(emotion_list, fontsize=25, rotation=30,
                   rotation_mode='anchor', position=(0, -0.06))

ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

ax.legend(loc="upper left", prop={'size': 25, }, ncol=4, bbox_to_anchor=(0.18, 1.1), fancybox=True,
          framealpha=0.0, labelspacing=0.1, handletextpad=0.3, columnspacing=0.5, handlelength=1.1)
# ax.legend(loc="upper center", prop={'size': 20,},ncol=3,bbox_to_anchor=(0.5, 1.2),fancybox=True, framealpha=0.0,labelspacing=0.1 ,handletextpad = 0.2)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(1)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.yaxis.set_tick_params(labelsize=25, length=4, direction='in', width=1)
ax.xaxis.set_tick_params(labelsize=25, length=2, direction='out', width=1)

# plt.tight_layout()

# fig.savefig(

# %%
'#FF545A', '#53a8fb','#64c44b'

# %%
kd = np.asarray([0.67543936, 0.3429233, -0.048263058, -0.057558905, 0.076596685, -0.023477986, -0.12846045])
ours = np.asarray([0.8297626, 0.67001975, 0.6317048, 0.31210327, 0.37531605, 0.22298682, 0.5658224])
imag = np.asarray([0.9002371, 0.75488144, 0.7042448, 0.5286966, 0.69267374, 0.7186437, 0.7337955])
unsup = np.asarray([0.6985147, 0.38075477, 0.2572334, -0.06282681, 0.034902457, -0.22179835, 0.37535214])
x = np.arange(len(kd))

# %%
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(kd)
print(ours)
print(imag)
print(unsup)
# Out:
# [0.675 0.343 -0.048 -0.058 0.077 -0.023 -0.128]
# [0.830 0.670 0.632 0.312 0.375 0.223 0.566]
# [0.900 0.755 0.704 0.529 0.693 0.719 0.734]
# [0.699 0.381 0.257 -0.063 0.035 -0.222 0.375]

# %%
fig, ax = plt.subplots(figsize=(8, 5.5))
colors =['#53a8fb', '#FF545A', '#FFBE54','#64c44b']
rects1 = ax.plot(x,kd,color=colors[0],linewidth=3, label = 'KD',marker='o',ms = 10,markeredgewidth = 2.5, markeredgecolor=colors[0])
# rects2 = ax.plot(x,smooth_decay,  markerfacecolor='blue', markersize=12, color='black', linewidth=2, label = 'decay')
rects2 = ax.plot(x,ours,color=colors[1],linewidth=3, label = 'mmFer',marker='o',ms = 10,markeredgewidth = 2.5, markeredgecolor=colors[1])
rects3 = ax.plot(x,unsup,color=colors[2],linewidth=3,label = 'S-cross',marker='o',ms = 10,markeredgewidth = 2.5,markeredgecolor=colors[2])
rects4 = ax.plot(x,imag,color=colors[3],linewidth=3,label = 'Image',marker='o',ms = 10,markeredgewidth = 2.5,markeredgecolor=colors[3])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel("Silhouette score", fontsize=35)
ax.set_xticks(x)
ax.set_xticklabels(emotion_list, fontsize=20, rotation=30,
                   rotation_mode='anchor', position=(0.0, -0.1))
ax.yaxis.set_tick_params(labelsize=30,length=5)
ax.xaxis.set_tick_params(labelsize=25,length=5)
ax.yaxis.set_major_locator(ticker.MultipleLocator(0.5))

ax.set_facecolor("none")

ax.set_ylim(-0.5, 1)
custom_lines = [Line2D([0], [0],linestyle ='-'  ,color=colors[0], lw=5),
                Line2D([0], [0],linestyle = '-' ,color=colors[1], lw=5),
                Line2D([0], [0], linestyle = '-'  ,color=colors[2], lw=5),
                Line2D([0], [0], linestyle = '-'  ,color=colors[3], lw=5)]

legend = ax.legend(custom_lines,['KD', 'mmFER', 'S-cross','Image'],loc='upper left',  prop={'size': 25,},columnspacing=0.4,
bbox_to_anchor=(-0.17, 1.3),ncol=4,handletextpad = 0.5,fancybox=True, framealpha=0.0,handlelength = 1.0)
#legend.get_frame().set_facecolor('C0') #set legend color
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
fig.savefig('C:/Users/Zber/Desktop/mmEmo_Exp/0.Method/Fig15.svg', format='svg', bbox_inches="tight")

# %%
kd_inter =np.asarray([0.62550694, 0.4070267, 0.38929537, 0.40352848, 0.39833614, 0.3273871, 0.3434379])
kd_intra = np.asarray([0.12564525, 0.14187963, 0.18943498, 0.18996643, 0.16647804, 0.18747783, 0.21978226])

our_inter =np.asarray([0.78693694, 0.7472032, 0.7208831, 0.69491565, 0.7151455, 0.59665686, 0.74576664])
our_intra = np.asarray([0.1250234, 0.20633757, 0.21008575, 0.37660676, 0.3050667, 0.36848816, 0.23403038])

image_inter = np.asarray([0.6060365, 0.65011424, 0.57981735, 0.5701012, 0.54260385, 0.49578214, 0.63147366])
image_intra = np.asarray([0.03015995, 0.057670075, 0.063411854, 0.06811954, 0.04953781, 0.053368185, 0.05260416])

kd = kd_inter/kd_intra
our = our_inter/our_intra
imag = image_inter/image_intra

# %%
import matplotlib.ticker as ticker
fig, ax = plt.subplots(1, 1, figsize=(8, 5.5))
colors =['#53a8fb', '#a97ddd', '#64c44b','#68dcf2', '#FF545A', '#FFBE54']
# colors1 = ['#c2342c',#ef8636]
emotion_list = ['Neutral', 'Happiness', 'Surprise','Anger', 'Sadness', 'Fear', 'Disgust']

ind = np.arange(1, len(kd)+1)
# np.arange(1,len(sit+1))*0.9  # the x locations for the groups
width = 0.2  # the width of the bars

rects0 = ax.bar(ind - width, kd, width, edgecolor = 'black',color=colors[-1],
                label='KD',linewidth=1)
rects1 = ax.bar(ind , ours, width, edgecolor='black', color=colors[-2],
                label='Our')
rects3 = ax.bar(ind + width, imag, width, edgecolor='black', label='Image', color=colors[2])


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel("Silhouette Score", fontsize=30)
# ax.set_xlabel("# Devices",fontsize=30)
# ax.set_title('battery variance',fontsize=18,fontweight="bold")
# ax.set_ylim(-1, 1)
ax.yaxis.set_tick_params(labelsize=25, length=5)
ax.set_xticks(ind)
ax.set_xticklabels(emotion_list, fontsize=25, rotation=30,
                   rotation_mode='anchor', position=(0, -0.06))

ax.yaxis.set_major_locator(ticker.MultipleLocator(5))

ax.legend(loc="upper left", prop={'size': 25, }, ncol=4, bbox_to_anchor=(0.18, 1.1), fancybox=True,
          framealpha=0.0, labelspacing=0.1, handletextpad=0.3, columnspacing=0.5, handlelength=1.1)
# ax.legend(loc="upper center", prop={'size': 20,},ncol=3,bbox_to_anchor=(0.5, 1.2),fancybox=True, framealpha=0.0,labelspacing=0.1 ,handletextpad = 0.2)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(1)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.yaxis.set_tick_params(labelsize=25, length=4, direction='in', width=1)
ax.xaxis.set_tick_params(labelsize=25, length=2, direction='out', width=1)
