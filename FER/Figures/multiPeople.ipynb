# %%
import os
os.chdir("C:\\Users\\Zber\\Documents\\Dev_program\\OpenRadar")
import numpy as np
import matplotlib.pyplot as plt

# %%
h_path = "FER/Figures/fig_data/multiPeople_heatmap_2.npy"
heatmap = np.load(h_path)
heatmap = heatmap[:, :-20]

nh = np.concatenate((heatmap[:, 4:35], heatmap[:, :4]*1.3, heatmap[:, :3]*1.3 , heatmap[:, 35:]) ,axis=1)

heatmap = nh

at1_path = "FER/Figures/fig_data/multiPeople_angle1.npy"
angle_time1 = np.load(at1_path)

at2_path = "FER/Figures/fig_data/multiPeople_angle2.npy"
angle_time2 = np.load(at2_path)

# %%
heatmap.shape
# Out:
# (121, 83)

# %%
fig1, axes1 = plt.subplots(1, 1, figsize=(8, 6))

plt.rcParams["axes.grid"] = False
txt = np.arange(-60, 61, step=20)
pos = np.linspace(1,119,7)
axes1.set_yticks(pos)
axes1.set_yticklabels(txt,fontsize=25)
xpos_label = np.arange(0,4, step=1)
xpos = xpos_label * 99.5
# axes1.axhline(54, c='#ff2100', label='Face-match',  lw=3, zorder=5)
# axes1.axhline(69, c='#ff2100', lw=3, zorder=5)



axes1.axhline(76, c='white', lw=3, linestyle='dashed')
axes1.axhline(96, c='white', lw=3, linestyle='dashed')

axes1.set_xticks(xpos)
axes1.set_xticklabels(xpos_label,fontsize=30)
axes1.set_ylabel("Angle (degree)",fontsize=35)
axes1.set_xlabel("Time (s)",fontsize=35)
axes1.imshow(angle_time1, cmap=plt.cm.jet, aspect='auto')
# axes1.legend(loc="upper left", prop={'size': 30, }, ncol=1, bbox_to_anchor=(0.0, 0.2), fancybox=True,
#       framealpha=0.0, labelspacing=0.05, handletextpad=0.2, columnspacing=0.5, handlelength=1.5)
# axes1.legend( prop={'size': 20, 'weight':'bold'})
# fig1.savefig('C:/Users/Zber/Desktop/mmEmo_Exp/0.Method/m1_5_aoa_time.svg', format='svg', bbox_inches="tight")
fig1.savefig('C:/Users/Zber/Desktop/mmEmo_Exp/0.Method/Fig14b_multiTarget.svg', format='svg', bbox_inches="tight")

# %%
fig1, axes1 = plt.subplots(1, 1, figsize=(8, 6))

plt.rcParams["axes.grid"] = False
txt = np.arange(-60, 61, step=20)
pos = np.linspace(1,119,7)
axes1.set_yticks(pos)
axes1.set_yticklabels(txt,fontsize=25)
xpos_label = np.arange(0,4, step=1)
xpos = xpos_label * 99.5
# axes1.axhline(54, c='#ff2100', label='Face-match',  lw=3, zorder=5)
# axes1.axhline(69, c='#ff2100', lw=3, zorder=5)



axes1.axhline(38, c='white', lw=3, linestyle='dashed')
axes1.axhline(58, c='white', lw=3, linestyle='dashed')

axes1.set_xticks(xpos)
axes1.set_xticklabels(xpos_label,fontsize=30)
axes1.set_ylabel("Angle (degree)",fontsize=35)
axes1.set_xlabel("Time (s)",fontsize=35)
axes1.imshow(angle_time2, cmap=plt.cm.jet, aspect='auto')
# axes1.legend(loc="upper left", prop={'size': 30, }, ncol=1, bbox_to_anchor=(0.0, 0.2), fancybox=True,
#       framealpha=0.0, labelspacing=0.05, handletextpad=0.2, columnspacing=0.5, handlelength=1.5)
# axes1.legend( prop={'size': 20, 'weight':'bold'})
# fig1.savefig('C:/Users/Zber/Desktop/mmEmo_Exp/0.Method/m1_5_aoa_time.svg', format='svg', bbox_inches="tight")
fig1.savefig('C:/Users/Zber/Desktop/mmEmo_Exp/0.Method/Fig14c_multiTarget.svg', format='svg', bbox_inches="tight")

# %%
# [16 17 18 19 20 21 34 35 36 37]

# %%
unit = 0.042158314406249994

fig1, axes1 = plt.subplots(1, 1, figsize=(8, 6))

x1 = (np.asarray([15, 22])+4)/83
x2 = (np.asarray([33, 38])+11)/83

plt.rcParams["axes.grid"] = False
txt = np.arange(-60, 61, step=20)
pos = np.linspace(1,119,7)
axes1.set_yticks(pos)
axes1.set_yticklabels(txt,fontsize=25)
xpos_label = np.arange(0,4, step=1)
xpos = xpos_label * 99.5
# axes1.axhline(54, c='#ff2100', label='Face-match',  lw=3, zorder=5)
# axes1.axhline(69, c='#ff2100', lw=3, zorder=5)


x_txt = np.arange(0,5, step=1)
x_pos = x_txt/unit
axes1.set_xticks(x_pos)
axes1.set_xticklabels(x_txt,fontsize=30)
axes1.axhline(43, c='white', lw=3,label='Ground Truth',  linestyle='dashed')
axes1.axhline(54, c='white', lw=3,linestyle='dashed')

axes1.axhline(79, c='white', lw=3,linestyle='dashed')
axes1.axhline(93, c='white', lw=3,linestyle='dashed')



# axes1.axvline(68, c='white', lw=3, linestyle='dashed')

axes1.set_ylabel("Angle (degree)",fontsize=35)
axes1.set_xlabel("Time (s)",fontsize=35)
axes1.imshow(heatmap, cmap=plt.cm.jet, aspect='auto')
axes1.set_xlabel("Range (m)",fontsize=35)
leg = axes1.legend(prop={'size': 20, 'weight':'bold'})
leg_lines = leg.get_lines()
plt.setp(leg_lines[0], linewidth=4)
# axes1.legend(loc="upper left", prop={'size': 30, }, ncol=1, bbox_to_anchor=(0.0, 0.2), fancybox=True,
#       framealpha=0.0, labelspacing=0.05, handletextpad=0.2, columnspacing=0.5, handlelength=1.5)
# axes1.legend( prop={'size': 20, 'weight':'bold'})
# fig1.savefig('C:/Users/Zber/Desktop/mmEmo_Exp/0.Method/m1_5_aoa_time.svg', format='svg', bbox_inches="tight")
fig1.savefig('C:/Users/Zber/Desktop/mmEmo_Exp/0.Method/Fig14_multiTarget.svg', format='svg', bbox_inches="tight")

# %%
x2 * 83 * unit
# Out:
# array([1.85496583, 2.06575741])

# %%
from matplotlib.patches import Rectangle
unit = 0.042158314406249994
x1 = (np.asarray([15, 22])+4)/83
x2 = (np.asarray([33, 38])+11)/83

y1 = np.asarray([78, 94]) /121
y2 = np.asarray([42, 56]) /121

colors =[
"#66ff66", 
# "red",
"#ffff00"]

fig1, axes1 = plt.subplots(1, 1, figsize=(8, 6))

plt.rcParams["axes.grid"] = False
txt = np.arange(-60, 61, step=20)
pos = np.linspace(1,119,7)
axes1.set_yticks(pos)
axes1.set_yticklabels(txt,fontsize=25)
xpos_label = np.arange(0,4, step=1)
xpos = xpos_label * 99.5
# axes1.axhline(54, c='#ff2100', label='Face-match',  lw=3, zorder=5)
# axes1.axhline(69, c='#ff2100', lw=3, zorder=5)


x_txt = np.arange(0,5, step=1)
x_pos = x_txt/unit
axes1.set_xticks(x_pos)
axes1.set_xticklabels(x_txt,fontsize=30)
axes1.axhline(43, c='white', lw=3,label='Ground Truth',  linestyle='dashed')
axes1.axhline(54, c='white', lw=3,linestyle='dashed')


axes1.add_patch( Rectangle((43, 42),
                        6, 14,
                        fc ='none', 
                        ec =colors[1],
                        lw = 3,
                        label='S2 Face RA',
                        zorder= 5
                        ) )



axes1.add_patch( Rectangle((18,78),
                        8, 16,
                        fc ='none', 
                        ec =colors[0],
                        lw = 3,
                        label='S1 Face RA',
                        zorder= 5
                        ) )


# axes1.axhline(42, xmin=x2[0], xmax=x2[1], c=colors[1], lw=3,linestyle='solid', label='S2 Face RA')
# axes1.axhline(56, xmin=x2[0], xmax=x2[1], c=colors[1], lw=3,linestyle='solid')
# axes1.axhline(78, xmin=x1[0], xmax=x1[1],c=colors[0], lw=3,linestyle='solid', label='S1 Face RA')
# axes1.axhline(94, xmin=x1[0], xmax=x1[1],c=colors[0], lw=3,linestyle='solid')




axes1.axhline(79, c='white', lw=3,linestyle='dashed')
axes1.axhline(93, c='white', lw=3,linestyle='dashed')


# axes1.axhline(78, xmin=x1[0], xmax=x1[1],c=colors[0], lw=3,linestyle='solid', label='S1 Face RA')
# axes1.axhline(94, xmin=x1[0], xmax=x1[1],c=colors[0], lw=3,linestyle='solid')

axes1.set_ylabel("Angle (degree)",fontsize=35)
axes1.set_xlabel("Time (s)",fontsize=35)
axes1.imshow(heatmap, cmap=plt.cm.jet, aspect='auto')
axes1.set_xlabel("Range (m)",fontsize=35)
leg = axes1.legend(prop={'size': 20, 'weight':'bold'},bbox_to_anchor=(1.02, 1.025),)
leg_lines = leg.get_lines()
plt.setp(leg_lines[0], linewidth=4)
# plt.setp(leg_lines[1], linewidth=4)
# plt.setp(leg_lines[2], linewidth=4)
# axes1.legend(loc="upper left", prop={'size': 30, }, ncol=1, bbox_to_anchor=(0.0, 0.2), fancybox=True,
#       framealpha=0.0, labelspacing=0.05, handletextpad=0.2, columnspacing=0.5, handlelength=1.5)
# axes1.legend( prop={'size': 20, 'weight':'bold'})
# fig1.savefig('C:/Users/Zber/Desktop/mmEmo_Exp/0.Method/m1_5_aoa_time.svg', format='svg', bbox_inches="tight")
fig1.savefig('C:/Users/Zber/Desktop/mmEmo_Exp/0.Method/Fig14_multiTarget_a.svg', format='svg', bbox_inches="tight")
#

# %%
a = [83.571429, 89.285714, 91.428571, 89.857143, 84.285714, 81.428571,  82.285714, 83.857143, 82.857143, 93.]
np.mean(a)
# Out:
# 86.18571419999999
